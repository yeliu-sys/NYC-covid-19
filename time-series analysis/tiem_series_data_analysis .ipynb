# %%
# import packages

# data processing
import pandas as pd
import numpy as np
from datetime import timedelta, datetime

import warnings

import statsmodels as sm
#import tensorflow as tf
import pmdarima as pm
from pylab import rcParams
from sklearn.linear_model import LinearRegression
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa import api as smt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

from gluonts.dataset.common import ListDataset
from gluonts.evaluation.backtest import make_evaluation_predictions
from gluonts.mx.model.deepar import DeepAREstimator
from gluonts.mx.trainer import Trainer
from matplotlib import pyplot as plt
from sklearn import linear_model, svm
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARIMA, ARMA
from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing
from statsmodels.tsa.statespace.sarimax import SARIMAX
from rich.progress import track

# We will use deprecated models of statmodels which throw a lot of warnings to use more modern ones
warnings.filterwarnings("ignore")

import re

# data visualization
from tabulate import tabulate
import plotly.graph_objs as go
from plotly.graph_objs import Bar, Layout
from plotly import offline
import plotly.io as pio
pio.renderers.default = 'iframe_connected'
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")
sns.set(rc={'figure.figsize':(11.7,8.27)})

plt.rcParams['font.sans-serif']=['Heiti TC']
plt.rcParams['axes.unicode_minus'] = False 

# change text color
import colorama
from colorama import Fore, Style

# IPython
from IPython.display import IFrame

# Extra settings
seed = 42
#tf.random.set_seed(seed)
np.random.seed(seed)
plt.style.use('bmh')
import matplotlib as mpl
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['text.color'] = 'k'
rcParams['figure.figsize'] = 18, 8

# change text color
import colorama
from colorama import Fore, Style

#print(tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 12
#      10 import statsmodels as sm
#      11 #import tensorflow as tf
# ---> 12 import pmdarima as pm
#      13 from pylab import rcParams
#      14 from sklearn.linear_model import LinearRegression
#
# File /opt/anaconda3/lib/python3.8/site-packages/pmdarima/__init__.py:52
#      49 from . import __check_build
#      51 # Stuff we want at top-level
# ---> 52 from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      53 from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      54     tsdisplay
#      55 from .utils._show_versions import show_versions
#
# File /opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/__init__.py:6
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
#       5 from .approx import *
# ----> 6 from .arima import *
#       7 from .auto import *
#       8 from .utils import *
#
# File /opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/arima.py:17
#      14 import numpy.polynomial.polynomial as np_polynomial
#      15 import warnings
# ---> 17 from . import _validation as val
#      18 from ..base import BaseARIMA
#      19 from ..compat.numpy import DTYPE  # DTYPE for arrays
#
# File /opt/anaconda3/lib/python3.8/site-packages/pmdarima/arima/_validation.py:10
#       8 import numpy as np
#       9 import warnings
# ---> 10 from sklearn import metrics
#      12 from pmdarima.warnings import ModelFitWarning
#      14 # The valid information criteria
#
# File /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/__init__.py:41
#      37 from ._classification import multilabel_confusion_matrix
#      39 from ._dist_metrics import DistanceMetric
# ---> 41 from . import cluster
#      42 from .cluster import adjusted_mutual_info_score
#      43 from .cluster import adjusted_rand_score
#
# File /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/cluster/__init__.py:22
#      20 from ._supervised import fowlkes_mallows_score
#      21 from ._supervised import entropy
# ---> 22 from ._unsupervised import silhouette_samples
#      23 from ._unsupervised import silhouette_score
#      24 from ._unsupervised import calinski_harabasz_score
#
# File /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/cluster/_unsupervised.py:16
#      14 from ...utils import check_X_y
#      15 from ...utils import _safe_indexing
# ---> 16 from ..pairwise import pairwise_distances_chunked
#      17 from ..pairwise import pairwise_distances
#      18 from ...preprocessing import LabelEncoder
#
# File /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:33
#      30 from ..utils.fixes import delayed
#      31 from ..utils.fixes import sp_version, parse_version
# ---> 33 from ._pairwise_distances_reduction import PairwiseDistancesArgKmin
#      34 from ._pairwise_fast import _chi2_kernel_fast, _sparse_manhattan
#      35 from ..exceptions import DataConversionWarning
#
# File /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_pairwise_distances_reduction/__init__.py:89
#       1 # Pairwise Distances Reductions
#       2 # =============================
#       3 #
#    (...)
#      85 #    using Generalized Matrix Multiplication over `float64` data (see the
#      86 #    docstring of :class:`GEMMTermComputer64` for details).
# ---> 89 from ._dispatcher import (
#      90     BaseDistancesReductionDispatcher,
#      91     ArgKmin,
#      92     RadiusNeighbors,
#      93     sqeuclidean_row_norms,
#      94 )
#      96 __all__ = [
#      97     "BaseDistancesReductionDispatcher",
#      98     "ArgKmin",
#      99     "RadiusNeighbors",
#     100     "sqeuclidean_row_norms",
#     101 ]
#
# File /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_pairwise_distances_reduction/_dispatcher.py:11
#       7 from scipy.sparse import isspmatrix_csr
#       9 from .._dist_metrics import BOOL_METRICS, METRIC_MAPPING
# ---> 11 from ._base import _sqeuclidean_row_norms32, _sqeuclidean_row_norms64
#      12 from ._argkmin import (
#      13     ArgKmin64,
#      14     ArgKmin32,
#      15 )
#      16 from ._radius_neighbors import (
#      17     RadiusNeighbors64,
#      18     RadiusNeighbors32,
#      19 )
#
# File sklearn/metrics/_pairwise_distances_reduction/_base.pyx:1, in init sklearn.metrics._pairwise_distances_reduction._base()
#
# AttributeError: module 'sklearn.metrics._dist_metrics' has no attribute 'DistanceMetric32'

# %%
# !pip uninstall pmdarima
# !pip install pmdarima==1.8.5
# Out:
# Found existing installation: pmdarima 1.8.5
# Uninstalling pmdarima-1.8.5:
#   Would remove:
#     /opt/anaconda3/lib/python3.8/site-packages/pmdarima-1.8.5.dist-info/*
#     /opt/anaconda3/lib/python3.8/site-packages/pmdarima/*
# Proceed (y/n)?

# %%
from getdata import GET_csse_covid_19_daily_reports,GET_csse_covid_19_time_series
from data_processing import ts_process_US,daily_process

# get data
latest_data_global,prev_data_global,latest_data_us,prev_data_us = GET_csse_covid_19_daily_reports()
ts_confirmed_us,ts_confirmed_global,ts_deaths_us,ts_deaths_global,ts_recovered_global = GET_csse_covid_19_time_series()
# Out:
# loading daily data......
# complete
# loading timeseries data......
# complete

# %%
ts_confirmed_US_incre,loc_data_us,sorted_state = ts_process_US(ts_confirmed_us,clip=False)
ts_deaths_US_incre,_,_,population = ts_process_US(ts_deaths_us,death = True,clip=False)
latest_data_US = daily_process(latest_data_us, country = 'US')
prev_data_US = daily_process(prev_data_us, country = 'US')

# %% [markdown]
# # Time series data analysis
# ### Negative increase

# %%
neg_incre_date_US = []
neg_incre_province_US = []
neg_incre_number_US = []
for r,c in sorted(zip(np.where(ts_confirmed_US_incre<0)[0],np.where(ts_confirmed_US_incre<0)[1]),key = lambda x: x[0],reverse=True):
    neg_incre_date_US.append(str(ts_confirmed_US_incre.index[r]))
    neg_incre_province_US.append(ts_confirmed_US_incre.columns[c])
    neg_incre_number_US.append(ts_confirmed_US_incre.iloc[r,c])
    
    
print(tabulate(sorted(zip(neg_incre_date_US,
                   neg_incre_province_US,
                   neg_incre_number_US),key = lambda x: abs(x[2]),reverse = True),
               headers = ['Negative growth date', 'Occurrence location', 'Quantity'],tablefmt = 'pretty'))
# Out:
# +----------------------+----------------------+----------+
# | Negative growth date | Occurrence location  | Quantity |
# +----------------------+----------------------+----------+
# | 2022-08-17 00:00:00  |       Florida        |  -27000  |
# | 2021-04-26 00:00:00  |      New Jersey      |  -9005   |
# | 2022-01-26 00:00:00  |       Alabama        |  -8780   |
# | 2022-10-26 00:00:00  |       Nebraska       |  -8099   |
# | 2021-04-17 00:00:00  |       Missouri       |  -7698   |
# | 2023-02-20 00:00:00  |       Missouri       |  -6071   |
# | 2023-03-05 00:00:00  |      Tennessee       |  -5128   |
# | 2021-03-11 00:00:00  |       Missouri       |  -4354   |
# | 2022-02-08 00:00:00  |     Pennsylvania     |  -4116   |
# | 2021-06-29 00:00:00  |      California      |  -3940   |
# | 2022-05-11 00:00:00  |       Nebraska       |  -3764   |
# | 2023-01-17 00:00:00  |       Colorado       |  -3133   |
# | 2022-05-05 00:00:00  |    South Carolina    |  -3073   |
# | 2022-08-30 00:00:00  |        Idaho         |  -2439   |
# | 2022-05-04 00:00:00  |      Washington      |  -2220   |
# | 2022-01-18 00:00:00  |        Nevada        |  -2153   |
# | 2020-03-29 00:00:00  |      California      |  -2019   |
# | 2022-11-08 00:00:00  |        Alaska        |  -1893   |
# | 2022-03-22 00:00:00  |       Missouri       |  -1543   |
# | 2021-09-22 00:00:00  |       Florida        |  -1448   |
# | 2021-04-06 00:00:00  |       Oklahoma       |  -1294   |
# | 2022-04-08 00:00:00  |       Delaware       |  -1283   |
# | 2021-09-22 00:00:00  |     Rhode Island     |  -1260   |
# | 2022-02-19 00:00:00  |      Washington      |  -1246   |
# | 2023-01-04 00:00:00  |       Kentucky       |  -1162   |
# | 2023-01-05 00:00:00  |        Nevada        |  -1132   |
# | 2022-05-03 00:00:00  |       Florida        |   -999   |
# | 2021-07-08 00:00:00  |         Iowa         |   -947   |
# | 2023-01-31 00:00:00  |       Wyoming        |   -601   |
# | 2022-07-18 00:00:00  |         Iowa         |   -473   |
# | 2022-11-15 00:00:00  |       Delaware       |   -435   |
# | 2020-04-25 00:00:00  |     Puerto Rico      |   -403   |
# | 2020-08-15 00:00:00  |       Arkansas       |   -400   |
# | 2021-06-06 00:00:00  |       Missouri       |   -368   |
# | 2022-04-19 00:00:00  |       Alabama        |   -364   |
# | 2020-09-03 00:00:00  |    Massachusetts     |   -281   |
# | 2020-04-01 00:00:00  |        Texas         |   -276   |
# | 2022-02-10 00:00:00  | District of Columbia |   -256   |
# | 2021-06-27 00:00:00  |       Virginia       |   -232   |
# | 2021-05-08 00:00:00  |      New Jersey      |   -221   |
# | 2022-10-30 00:00:00  |      New Jersey      |   -220   |
# | 2022-02-24 00:00:00  |      Washington      |   -207   |
# | 2022-01-22 00:00:00  |      Washington      |   -191   |
# | 2021-09-25 00:00:00  |       Virginia       |   -172   |
# | 2022-05-19 00:00:00  |       Georgia        |   -160   |
# | 2022-02-28 00:00:00  |       Florida        |   -133   |
# | 2020-09-25 00:00:00  |     Rhode Island     |   -130   |
# | 2021-01-05 00:00:00  |        Kansas        |   -122   |
# | 2020-06-19 00:00:00  |      Louisiana       |   -119   |
# | 2022-02-17 00:00:00  |      Washington      |   -112   |
# | 2022-04-01 00:00:00  |       Nebraska       |   -107   |
# | 2022-02-15 00:00:00  |     Puerto Rico      |   -101   |
# | 2023-01-10 00:00:00  |       Kentucky       |   -84    |
# | 2020-12-15 00:00:00  |        Hawaii        |   -79    |
# | 2022-05-29 00:00:00  |       Nebraska       |   -78    |
# | 2022-03-12 00:00:00  |       Florida        |   -67    |
# | 2020-04-14 00:00:00  |    New Hampshire     |   -63    |
# | 2022-10-21 00:00:00  |       Illinois       |   -58    |
# | 2022-11-12 00:00:00  |       Virginia       |   -53    |
# | 2020-05-10 00:00:00  |        Nevada        |   -51    |
# | 2022-02-16 00:00:00  |      Washington      |   -47    |
# | 2020-04-22 00:00:00  |     Puerto Rico      |   -46    |
# | 2022-03-24 00:00:00  |       Nebraska       |   -44    |
# | 2020-05-17 00:00:00  |       Nebraska       |   -43    |
# | 2020-03-15 00:00:00  |      Washington      |   -39    |
# | 2020-04-27 00:00:00  |        Nevada        |   -34    |
# | 2021-03-13 00:00:00  |        Hawaii        |   -33    |
# | 2020-12-13 00:00:00  |        Hawaii        |   -32    |
# | 2022-06-02 00:00:00  |       Maryland       |   -27    |
# | 2020-07-25 00:00:00  |       Delaware       |   -27    |
# | 2022-04-12 00:00:00  |       Wyoming        |   -23    |
# | 2022-07-19 00:00:00  |      Washington      |   -22    |
# | 2021-11-25 00:00:00  |    South Carolina    |   -22    |
# | 2020-04-23 00:00:00  |     Puerto Rico      |   -22    |
# | 2021-05-13 00:00:00  |     Rhode Island     |   -21    |
# | 2020-04-11 00:00:00  |        Nevada        |   -20    |
# | 2021-07-09 00:00:00  |     Rhode Island     |   -19    |
# | 2023-01-26 00:00:00  |      Washington      |   -15    |
# | 2020-05-27 00:00:00  |     Connecticut      |   -15    |
# | 2022-03-22 00:00:00  |       Nebraska       |   -13    |
# | 2022-02-19 00:00:00  |       Michigan       |   -13    |
# | 2020-08-18 00:00:00  |     Connecticut      |   -12    |
# | 2021-02-08 00:00:00  |        Hawaii        |   -11    |
# | 2020-08-27 00:00:00  |       Delaware       |   -10    |
# | 2020-03-15 00:00:00  |       Arkansas       |    -9    |
# | 2022-10-26 00:00:00  |       Oklahoma       |    -8    |
# | 2022-06-25 00:00:00  |       Nebraska       |    -8    |
# | 2020-08-29 00:00:00  |       Wyoming        |    -8    |
# | 2020-08-10 00:00:00  |       Wyoming        |    -8    |
# | 2020-07-19 00:00:00  |      New Jersey      |    -8    |
# | 2021-10-10 00:00:00  |        Maine         |    -7    |
# | 2020-04-21 00:00:00  |    South Carolina    |    -7    |
# | 2022-07-14 00:00:00  |      Washington      |    -6    |
# | 2020-08-30 00:00:00  |       Delaware       |    -6    |
# | 2020-05-22 00:00:00  |        Hawaii        |    -5    |
# | 2021-06-14 00:00:00  |     South Dakota     |    -4    |
# | 2020-12-28 00:00:00  |        Hawaii        |    -4    |
# | 2020-05-06 00:00:00  |    West Virginia     |    -4    |
# | 2023-02-21 00:00:00  |       Nebraska       |    -3    |
# | 2021-06-16 00:00:00  |       Delaware       |    -3    |
# | 2020-05-02 00:00:00  |       Kentucky       |    -3    |
# | 2020-03-15 00:00:00  |       Maryland       |    -3    |
# | 2020-03-12 00:00:00  |    South Carolina    |    -3    |
# | 2022-05-02 00:00:00  |    South Carolina    |    -2    |
# | 2020-12-22 00:00:00  |        Hawaii        |    -2    |
# | 2020-06-23 00:00:00  |        Idaho         |    -2    |
# | 2020-05-31 00:00:00  |     Puerto Rico      |    -2    |
# | 2020-03-12 00:00:00  |     Rhode Island     |    -2    |
# | 2022-10-16 00:00:00  |        Maine         |    -1    |
# | 2022-07-27 00:00:00  |       Wyoming        |    -1    |
# | 2022-07-24 00:00:00  |        Maine         |    -1    |
# | 2022-03-30 00:00:00  |       Nebraska       |    -1    |
# | 2022-03-27 00:00:00  |       Illinois       |    -1    |
# | 2022-03-26 00:00:00  |       Illinois       |    -1    |
# | 2021-11-15 00:00:00  |        Maine         |    -1    |
# | 2021-10-18 00:00:00  |        Maine         |    -1    |
# | 2021-10-12 00:00:00  |        Maine         |    -1    |
# | 2021-08-09 00:00:00  |        Maine         |    -1    |
# | 2020-09-09 00:00:00  |        Maine         |    -1    |
# | 2020-07-22 00:00:00  |        Maine         |    -1    |
# | 2020-06-17 00:00:00  |       Vermont        |    -1    |
# | 2020-06-06 00:00:00  |       Montana        |    -1    |
# | 2020-05-20 00:00:00  |     Puerto Rico      |    -1    |
# | 2020-05-14 00:00:00  |        Hawaii        |    -1    |
# | 2020-05-11 00:00:00  |       Vermont        |    -1    |
# | 2020-05-05 00:00:00  |       Montana        |    -1    |
# | 2020-03-15 00:00:00  |       Nebraska       |    -1    |
# | 2020-03-15 00:00:00  |        Maine         |    -1    |
# | 2020-03-12 00:00:00  |     South Dakota     |    -1    |
# | 2020-03-11 00:00:00  |        Hawaii        |    -1    |
# +----------------------+----------------------+----------+

# %%
def negincre_report(ts_data, sort_by = 0):
    """
    ts_data: time seris data
    sort_by: 0 ==> date
             1 ==> place 
             2 ==> number
    """
    neg_incre_date = []
    neg_incre_province = []
    neg_incre_number = []
    for r,c in sorted(zip(np.where(ts_data<0)[0],np.where(ts_data<0)[1]),key = lambda x: x[0],reverse=True):
        neg_incre_date.append(str(ts_data.index[r]))
        neg_incre_province.append(ts_data.columns[c])
        neg_incre_number.append(ts_data.iloc[r,c])
    
    if sort_by == 0:
        table = sorted(zip(neg_incre_date,
                          neg_incre_province,
                          neg_incre_number),key = lambda x: x[0],reverse = True)
    elif sort_by == 1:
        table = sorted(zip(neg_incre_date,
                          neg_incre_province,
                          neg_incre_number),key = lambda x: x[1],reverse = True)
    else:
        table = sorted(zip(neg_incre_date,
                           neg_incre_province,
                           neg_incre_number),key = lambda x: abs(x[2]),reverse = True)
    
    print(tabulate(table, headers = ['Negative growth date', 'Occurrence location', 'Quantity'],tablefmt = 'pretty'))

# %%
negincre_report(ts_confirmed_US_incre,sort_by=2)
# Out:
# +----------------------+----------------------+----------+
# | Negative growth date | Occurrence location  | Quantity |
# +----------------------+----------------------+----------+
# | 2022-08-17 00:00:00  |       Florida        |  -27000  |
# | 2021-04-26 00:00:00  |      New Jersey      |  -9005   |
# | 2022-01-26 00:00:00  |       Alabama        |  -8780   |
# | 2022-10-26 00:00:00  |       Nebraska       |  -8099   |
# | 2021-04-17 00:00:00  |       Missouri       |  -7698   |
# | 2023-02-20 00:00:00  |       Missouri       |  -6071   |
# | 2023-03-05 00:00:00  |      Tennessee       |  -5128   |
# | 2021-03-11 00:00:00  |       Missouri       |  -4354   |
# | 2022-02-08 00:00:00  |     Pennsylvania     |  -4116   |
# | 2021-06-29 00:00:00  |      California      |  -3940   |
# | 2022-05-11 00:00:00  |       Nebraska       |  -3764   |
# | 2023-01-17 00:00:00  |       Colorado       |  -3133   |
# | 2022-05-05 00:00:00  |    South Carolina    |  -3073   |
# | 2022-08-30 00:00:00  |        Idaho         |  -2439   |
# | 2022-05-04 00:00:00  |      Washington      |  -2220   |
# | 2022-01-18 00:00:00  |        Nevada        |  -2153   |
# | 2020-03-29 00:00:00  |      California      |  -2019   |
# | 2022-11-08 00:00:00  |        Alaska        |  -1893   |
# | 2022-03-22 00:00:00  |       Missouri       |  -1543   |
# | 2021-09-22 00:00:00  |       Florida        |  -1448   |
# | 2021-04-06 00:00:00  |       Oklahoma       |  -1294   |
# | 2022-04-08 00:00:00  |       Delaware       |  -1283   |
# | 2021-09-22 00:00:00  |     Rhode Island     |  -1260   |
# | 2022-02-19 00:00:00  |      Washington      |  -1246   |
# | 2023-01-04 00:00:00  |       Kentucky       |  -1162   |
# | 2023-01-05 00:00:00  |        Nevada        |  -1132   |
# | 2022-05-03 00:00:00  |       Florida        |   -999   |
# | 2021-07-08 00:00:00  |         Iowa         |   -947   |
# | 2023-01-31 00:00:00  |       Wyoming        |   -601   |
# | 2022-07-18 00:00:00  |         Iowa         |   -473   |
# | 2022-11-15 00:00:00  |       Delaware       |   -435   |
# | 2020-04-25 00:00:00  |     Puerto Rico      |   -403   |
# | 2020-08-15 00:00:00  |       Arkansas       |   -400   |
# | 2021-06-06 00:00:00  |       Missouri       |   -368   |
# | 2022-04-19 00:00:00  |       Alabama        |   -364   |
# | 2020-09-03 00:00:00  |    Massachusetts     |   -281   |
# | 2020-04-01 00:00:00  |        Texas         |   -276   |
# | 2022-02-10 00:00:00  | District of Columbia |   -256   |
# | 2021-06-27 00:00:00  |       Virginia       |   -232   |
# | 2021-05-08 00:00:00  |      New Jersey      |   -221   |
# | 2022-10-30 00:00:00  |      New Jersey      |   -220   |
# | 2022-02-24 00:00:00  |      Washington      |   -207   |
# | 2022-01-22 00:00:00  |      Washington      |   -191   |
# | 2021-09-25 00:00:00  |       Virginia       |   -172   |
# | 2022-05-19 00:00:00  |       Georgia        |   -160   |
# | 2022-02-28 00:00:00  |       Florida        |   -133   |
# | 2020-09-25 00:00:00  |     Rhode Island     |   -130   |
# | 2021-01-05 00:00:00  |        Kansas        |   -122   |
# | 2020-06-19 00:00:00  |      Louisiana       |   -119   |
# | 2022-02-17 00:00:00  |      Washington      |   -112   |
# | 2022-04-01 00:00:00  |       Nebraska       |   -107   |
# | 2022-02-15 00:00:00  |     Puerto Rico      |   -101   |
# | 2023-01-10 00:00:00  |       Kentucky       |   -84    |
# | 2020-12-15 00:00:00  |        Hawaii        |   -79    |
# | 2022-05-29 00:00:00  |       Nebraska       |   -78    |
# | 2022-03-12 00:00:00  |       Florida        |   -67    |
# | 2020-04-14 00:00:00  |    New Hampshire     |   -63    |
# | 2022-10-21 00:00:00  |       Illinois       |   -58    |
# | 2022-11-12 00:00:00  |       Virginia       |   -53    |
# | 2020-05-10 00:00:00  |        Nevada        |   -51    |
# | 2022-02-16 00:00:00  |      Washington      |   -47    |
# | 2020-04-22 00:00:00  |     Puerto Rico      |   -46    |
# | 2022-03-24 00:00:00  |       Nebraska       |   -44    |
# | 2020-05-17 00:00:00  |       Nebraska       |   -43    |
# | 2020-03-15 00:00:00  |      Washington      |   -39    |
# | 2020-04-27 00:00:00  |        Nevada        |   -34    |
# | 2021-03-13 00:00:00  |        Hawaii        |   -33    |
# | 2020-12-13 00:00:00  |        Hawaii        |   -32    |
# | 2022-06-02 00:00:00  |       Maryland       |   -27    |
# | 2020-07-25 00:00:00  |       Delaware       |   -27    |
# | 2022-04-12 00:00:00  |       Wyoming        |   -23    |
# | 2022-07-19 00:00:00  |      Washington      |   -22    |
# | 2021-11-25 00:00:00  |    South Carolina    |   -22    |
# | 2020-04-23 00:00:00  |     Puerto Rico      |   -22    |
# | 2021-05-13 00:00:00  |     Rhode Island     |   -21    |
# | 2020-04-11 00:00:00  |        Nevada        |   -20    |
# | 2021-07-09 00:00:00  |     Rhode Island     |   -19    |
# | 2023-01-26 00:00:00  |      Washington      |   -15    |
# | 2020-05-27 00:00:00  |     Connecticut      |   -15    |
# | 2022-03-22 00:00:00  |       Nebraska       |   -13    |
# | 2022-02-19 00:00:00  |       Michigan       |   -13    |
# | 2020-08-18 00:00:00  |     Connecticut      |   -12    |
# | 2021-02-08 00:00:00  |        Hawaii        |   -11    |
# | 2020-08-27 00:00:00  |       Delaware       |   -10    |
# | 2020-03-15 00:00:00  |       Arkansas       |    -9    |
# | 2022-10-26 00:00:00  |       Oklahoma       |    -8    |
# | 2022-06-25 00:00:00  |       Nebraska       |    -8    |
# | 2020-08-29 00:00:00  |       Wyoming        |    -8    |
# | 2020-08-10 00:00:00  |       Wyoming        |    -8    |
# | 2020-07-19 00:00:00  |      New Jersey      |    -8    |
# | 2021-10-10 00:00:00  |        Maine         |    -7    |
# | 2020-04-21 00:00:00  |    South Carolina    |    -7    |
# | 2022-07-14 00:00:00  |      Washington      |    -6    |
# | 2020-08-30 00:00:00  |       Delaware       |    -6    |
# | 2020-05-22 00:00:00  |        Hawaii        |    -5    |
# | 2021-06-14 00:00:00  |     South Dakota     |    -4    |
# | 2020-12-28 00:00:00  |        Hawaii        |    -4    |
# | 2020-05-06 00:00:00  |    West Virginia     |    -4    |
# | 2023-02-21 00:00:00  |       Nebraska       |    -3    |
# | 2021-06-16 00:00:00  |       Delaware       |    -3    |
# | 2020-05-02 00:00:00  |       Kentucky       |    -3    |
# | 2020-03-15 00:00:00  |       Maryland       |    -3    |
# | 2020-03-12 00:00:00  |    South Carolina    |    -3    |
# | 2022-05-02 00:00:00  |    South Carolina    |    -2    |
# | 2020-12-22 00:00:00  |        Hawaii        |    -2    |
# | 2020-06-23 00:00:00  |        Idaho         |    -2    |
# | 2020-05-31 00:00:00  |     Puerto Rico      |    -2    |
# | 2020-03-12 00:00:00  |     Rhode Island     |    -2    |
# | 2022-10-16 00:00:00  |        Maine         |    -1    |
# | 2022-07-27 00:00:00  |       Wyoming        |    -1    |
# | 2022-07-24 00:00:00  |        Maine         |    -1    |
# | 2022-03-30 00:00:00  |       Nebraska       |    -1    |
# | 2022-03-27 00:00:00  |       Illinois       |    -1    |
# | 2022-03-26 00:00:00  |       Illinois       |    -1    |
# | 2021-11-15 00:00:00  |        Maine         |    -1    |
# | 2021-10-18 00:00:00  |        Maine         |    -1    |
# | 2021-10-12 00:00:00  |        Maine         |    -1    |
# | 2021-08-09 00:00:00  |        Maine         |    -1    |
# | 2020-09-09 00:00:00  |        Maine         |    -1    |
# | 2020-07-22 00:00:00  |        Maine         |    -1    |
# | 2020-06-17 00:00:00  |       Vermont        |    -1    |
# | 2020-06-06 00:00:00  |       Montana        |    -1    |
# | 2020-05-20 00:00:00  |     Puerto Rico      |    -1    |
# | 2020-05-14 00:00:00  |        Hawaii        |    -1    |
# | 2020-05-11 00:00:00  |       Vermont        |    -1    |
# | 2020-05-05 00:00:00  |       Montana        |    -1    |
# | 2020-03-15 00:00:00  |       Nebraska       |    -1    |
# | 2020-03-15 00:00:00  |        Maine         |    -1    |
# | 2020-03-12 00:00:00  |     South Dakota     |    -1    |
# | 2020-03-11 00:00:00  |        Hawaii        |    -1    |
# +----------------------+----------------------+----------+

# %%
data_copy1 = ts_confirmed_US_incre

specify = 'New York'
idx = data_copy1.index
ser = data_copy1[specify]
layout_title = specify.upper()
kind = 'Confirmed'
method = 'New'
ma = [7,30]

trace = go.Scatter(
            x = idx,
            y = ser,
            mode = 'lines+markers',
            name = f'{method}{kind}number',
            opacity = .8,
            line=dict(color="#08a8c4",width = .4),
            marker = dict(color = '#5857e1',size = 1.2)
        )
trace1 = go.Scatter(
    x = idx,
    y = ser.rolling(ma[0]).mean(),
    mode = 'lines+markers',
    name = f'{ma[0]}days moving average',
    opacity = .6,
    line=dict(color="#ee5090",width = 1.4),
    marker = dict(color = '#dd001b',size = 2.2)
)
trace2 = go.Scatter(
    x = idx,
    y = ser.rolling(ma[1]).mean(),
    mode = 'lines+markers',
    name = f'{ma[1]}days moving average',
    opacity = .8,
    line=dict(color="#006eff",width = 2.4),
    marker = dict(color = '#412b63',size = 3.2)
)


plotdata = [trace,trace1,trace2]

'''plotting'''

x_axis_config = {'title': 'date'}
y_axis_config = {'title': f'{kind}number（{method.upper()}）'}

my_layout = Layout(title=f"【{layout_title}】Recently【{kind}】Time Series Line Chart（{method.upper()}）",
                   xaxis=x_axis_config, yaxis=y_axis_config)

offline.iplot({'data': plotdata, 'layout': my_layout}, filename=f'{layout_title}_COVID_TS',image_height=500,image_width=1000,image = 'png')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_10.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
data_copy1 = ts_confirmed_US_incre

specify = 'US'
idx = data_copy1.index
ser = data_copy1.sum(axis=1)
layout_title = specify.upper()
kind = 'Confirmed'
method = 'New'
ma = [7,30]

trace = go.Scatter(
            x = idx,
            y = ser,
            mode = 'lines+markers',
            name = f'{method}{kind}number',
            opacity = .8,
            line=dict(color="#08a8c4",width = .4),
            marker = dict(color = '#5857e1',size = 1.2)
        )
trace1 = go.Scatter(
    x = idx,
    y = ser.rolling(ma[0]).mean(),
    mode = 'lines+markers',
    name = f'{ma[0]}days moving average',
    opacity = .6,
    line=dict(color="#ee5090",width = 1.4),
    marker = dict(color = '#dd001b',size = 2.2)
)
trace2 = go.Scatter(
    x = idx,
    y = ser.rolling(ma[1]).mean(),
    mode = 'lines+markers',
    name = f'{ma[1]}days moving average',
    opacity = .8,
    line=dict(color="#006eff",width = 2.4),
    marker = dict(color = '#412b63',size = 3.2)
)


plotdata = [trace,trace1,trace2]

'''plotting'''

x_axis_config = {'title': 'date'}
y_axis_config = {'title': f'{kind}number（{method.upper()}）'}

my_layout = Layout(title=f"【{layout_title}】Recently【{kind}】Time Series Line Chart（{method.upper()}）",
                   xaxis=x_axis_config, yaxis=y_axis_config)

offline.iplot({'data': plotdata, 'layout': my_layout}, filename=f'{layout_title}_COVID_TS',image_height=500,image_width=1000,image = 'png')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_12.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
data_copy1 = ts_deaths_US_incre

specify = 'US'
idx = data_copy1.index
ser = data_copy1.sum(axis=1)
layout_title = specify.upper()
kind = 'Death'
method = 'New'
ma = [7,30]

trace = go.Scatter(
            x = idx,
            y = ser,
            mode = 'lines+markers',
            name = f'{method}{kind}number',
            opacity = .8,
            line=dict(color="#08a8c4",width = .4),
            marker = dict(color = '#5857e1',size = 1.2)
        )
trace1 = go.Scatter(
    x = idx,
    y = ser.rolling(ma[0]).mean(),
    mode = 'lines+markers',
    name = f'{ma[0]}days moving average',
    opacity = .6,
    line=dict(color="#ee5090",width = 1.4),
    marker = dict(color = '#dd001b',size = 2.2)
)
trace2 = go.Scatter(
    x = idx,
    y = ser.rolling(ma[1]).mean(),
    mode = 'lines+markers',
    name = f'{ma[1]}days moving average',
    opacity = .8,
    line=dict(color="#006eff",width = 2.4),
    marker = dict(color = '#412b63',size = 3.2)
)


plotdata = [trace,trace1,trace2]

'''plotting'''

x_axis_config = {'title': 'date'}
y_axis_config = {'title': f'{kind}number（{method.upper()}）'}

my_layout = Layout(title=f"【{layout_title}】Recently【{kind}】Time Series Line Chart（{method.upper()}）",
                   xaxis=x_axis_config, yaxis=y_axis_config)

offline.iplot({'data': plotdata, 'layout': my_layout}, filename=f'{layout_title}_COVID_TS',image_height=500,image_width=1000,image = 'png')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_13.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Season Variation

# %%
# New York
nyc_series = ts_confirmed_US_incre['New York']
nyc_result = seasonal_decompose(nyc_series, model = 'additive')
nyc_result.plot()
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
fig = plt.figure(figsize=(15, 7))
layout = (3, 2)
pm_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
mv_ax = plt.subplot2grid(layout, (1, 0), colspan=2)
fit_ax = plt.subplot2grid(layout, (2, 0), colspan=2)

nyc_series = ts_confirmed_US_incre['New York']

nyc_result = seasonal_decompose(nyc_series, model = 'additive')
nyc_result.trend.plot(ax = pm_ax)
pm_ax.set_title("NYC Automatic decomposed trend")

nyc_result1 = seasonal_decompose(nyc_series, model = 'additive', period = 30)
nyc_result1.trend.plot(ax = mv_ax)
mv_ax.set_title("30 Days Moving average")

x = [i for i in range(0, len(nyc_series))]
x = np.reshape(x,(len(x),1))
reg = LinearRegression().fit(x,nyc_series)
trend = reg.predict(x)
fit_ax.plot(trend)
fit_ax.set_title("Trend fitted by linear regression")

plt.tight_layout()

# %%
plt.subplot(411)
nyc_series = ts_confirmed_US_incre['New York']
nyc_result = seasonal_decompose(nyc_series, model='additive')
nyc_result.seasonal.plot()
plt.ylabel('Total')
plt.subplot(412)
nyc_series_2020 = ts_confirmed_US_incre['New York'][ts_confirmed_US_incre.index<'2021']
nyc_result_2020 = seasonal_decompose(nyc_series_2020, model='additive')
nyc_result_2020.seasonal.plot()
plt.ylabel('2020')
plt.subplot(413)
nyc_series_2021 = ts_confirmed_US_incre['New York'][(ts_confirmed_US_incre.index>'2021') &(ts_confirmed_US_incre.index<'2022')]
nyc_result_2021 = seasonal_decompose(nyc_series_2021, model='additive')
nyc_result_2021.seasonal.plot()
plt.ylabel('2021')
plt.subplot(414)
nyc_series_2022 = ts_confirmed_US_incre['New York'][ts_confirmed_US_incre.index>'2022']
nyc_result_2022 = seasonal_decompose(nyc_series_2022, model='additive')
nyc_result_2022.seasonal.plot()
plt.ylabel('2022')
# Out:
# Text(0, 0.5, '2022')

# %%
fig = plt.figure(figsize=(12, 7))
layout = (2, 2)
hist_ax = plt.subplot2grid(layout, (0, 0))
ac_ax = plt.subplot2grid(layout, (1, 0))
hist_std_ax = plt.subplot2grid(layout, (0, 1))
mean_ax = plt.subplot2grid(layout, (1, 1))

nyc_series.hist(ax=hist_ax)
hist_ax.set_title("Original series histogram")

plot_acf(nyc_series, lags=30, ax=ac_ax)
ac_ax.set_title("Autocorrelation")

mm = nyc_series.rolling(7).std()
mm.hist(ax=hist_std_ax)
hist_std_ax.set_title("Standard deviation histogram")

mm = nyc_series.rolling(30).mean()
mm.plot(ax=mean_ax)
mean_ax.set_title("Mean over time")
# Out:
# Text(0.5, 1.0, 'Mean over time')

# %%
rolmean = nyc_series.rolling(window=30).mean()
rolstd = nyc_series.rolling(window=30).std()

# Plot rolling statistics:
orig = plt.plot(nyc_series, label='Original',alpha = .3)
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='green', label='Rolling Std')
plt.legend()
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %%
X = nyc_series
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -3.977112
# p-value: 0.001535
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568

# %%
def tsplot(y, lags=None, figsize=(12, 7), ma = 30, decompose = True):
    if not isinstance(y, pd.Series):
        y = pd.Series(y)

    with plt.style.context(style='bmh'):
        fig = plt.figure(figsize=(12, 7))
        layout = (3, 2)
        ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1, 0))
        pacf_ax = plt.subplot2grid(layout, (1, 1))
        mean_std_ax = plt.subplot2grid(layout, (2, 0), colspan=2)
        #y.plot.area(ax=ts_ax)
        ts_ax.step(y.index,y,color = '#202124',linewidth = .5)
        ts_ax.bar(y.index,y,alpha = .8)
        
        p_value = sm.tsa.stattools.adfuller(y)[1]
        hypothesis_result = "We reject H0 and the series is stationary" if p_value <= 0.05 else "We can not reject H0 and the series is NOT stationary"
        ts_ax.set_title(
            'Time Series Stationary Analysis Plots\n Dickey-Fuller: p={0:.5f} \n Result: {1}'.format(p_value, hypothesis_result),
        fontsize = 20)
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax)
        plt.tight_layout()

        rolmean = y.rolling(window=ma).mean()
        rolstd = y.rolling(window=ma).std()

        # Plot rolling statistics:
        orig = plt.plot(y, label='Original',alpha = .3)
        mean = plt.plot(rolmean, color='red', label='Rolling Mean')
        std = plt.plot(rolstd, color='black', label='Rolling Std')
        plt.legend(loc='best')
        plt.title('Rolling Mean & Standard Deviation')
        print(f"ADF test results：{Fore.RED}{hypothesis_result}{Style.RESET_ALL}")
        print(f"ADF test p-values：{Fore.BLUE}{round(p_value,6)}{Style.RESET_ALL}")
    if decompose:
        plt.rcParams["figure.figsize"] = (12,8)
        result = seasonal_decompose(y, model='additive')
        result.plot()
        plt.show() 

tsplot(nyc_series, lags=30)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# ADF test results：We reject H0 and the series is stationary
# ADF test p-values：0.001535

# %%
split_date = '2022-01-01'
df_train = ts_confirmed_US_incre.loc[ts_confirmed_US_incre.index < split_date]
df_test = ts_confirmed_US_incre.loc[ts_confirmed_US_incre.index >= split_date]
print(f"{len(df_train)} days of training data \n {len(df_test)} days of testing data ")
# Out:
# 710 days of training data
#  433 days of testing data

# %%
resultsDict = {}
predictionsDict = {}

# %%
def evaluate(actual, predicted):
    """
    Evaluate model predictions against actual values
    
    Parameters:
    actual (array-like): The actual values
    predicted (array-like): The predicted values
    
    Returns:
    dict: Dictionary containing error metrics (like MAE, MSE, RMSE)
    """
    import numpy as np
    
    # Convert inputs to numpy arrays
    actual = np.array(actual)
    predicted = np.array(predicted)
    
    # Calculate error metrics
    mae = np.mean(np.abs(actual - predicted))  # Mean Absolute Error
    mse = np.mean((actual - predicted) ** 2)   # Mean Squared Error
    rmse = np.sqrt(mse)                        # Root Mean Squared Error
    
    return {
        'MAE': mae,
        'MSE': mse,
        'RMSE': rmse
    }

# %%
mean = df_train['New York'].mean() 
mean = np.array([mean for u in range(len(df_test))]) 
resultsDict['Naive mean'] = evaluate(df_test['New York'], mean) 
predictionsDict['Naive mean'] = mean 
resultsDict['Yesterdays value'] = evaluate(
    df_test['New York'], df_test['New York'].shift(1).fillna(0))

predictionsDict['Yesterdays value'] = df_test['New York'].shift(1).fillna(0).values

# %%
# Walk throught the test data, training and predicting 1 day ahead for all the test data
index = len(df_train)
yhat = list()
for t in track(range(len(df_test['New York']))):
    temp_train = ts_confirmed_US_incre[:index+t]
    model = SimpleExpSmoothing(temp_train['New York'])
    model_fit = model.fit()
    predictions = model_fit.predict(len(temp_train),len(temp_train))
    yhat = yhat + [predictions]

yhat_SES = pd.concat(yhat)
resultsDict['SES'] = evaluate(df_test['New York'], yhat_SES.values)
predictionsDict['SES'] = yhat_SES.values
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# Walk throught the test data, training and predicting 1 day ahead for all the test data
index = len(df_train)
yhat = list()
for t in track(range(len(df_test['New York']))):
    temp_train = ts_confirmed_US_incre[:index+t]
    model = ExponentialSmoothing(temp_train['New York'])
    model_fit = model.fit()
    predictions = model_fit.predict(len(temp_train),len(temp_train))
    yhat = yhat + [predictions]
    
yhat_HWES = pd.concat(yhat)
resultsDict['HWES'] = evaluate(df_test['New York'], yhat_HWES.values)
predictionsDict['HWES'] = yhat_HWES.values
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# Walk throught the test data, training and predicting 1 day ahead for all the test data
index = len(df_train)
yhat = list()
for t in track(range(len(df_test['New York']))):
    temp_train = ts_confirmed_US_incre[:index+t]
    model = AR(temp_train['New York'])
    model_fit = model.fit()
    predictions = model_fit.predict(len(temp_train),len(temp_train))
    yhat = yhat + [predictions]

yhat_AR = pd.concat(yhat)
resultsDict['AR'] = evaluate(df_test['New York'], yhat_AR.values)
predictionsDict['AR'] = yhat_AR.values
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# Walk throught the test data, training and predicting 1 day ahead for all the test data
index = len(df_train)
yhat = list()
for t in track(range(len(df_test['New York']))):
    temp_train = ts_confirmed_US_incre[:index+t]
    model = ARMA(temp_train['New York'],order=(0,1))
    model_fit = model.fit()
    predictions = model_fit.predict(len(temp_train),len(temp_train))
    yhat = yhat + [predictions]

yhat_MA = pd.concat(yhat)
resultsDict['MA'] = evaluate(df_test['New York'], yhat_MA.values)
predictionsDict['MA'] = yhat_MA.values
# Out:
# Output()
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00685D+01    |proj g|=  2.70539D-04
#
# At iterate    5    f=  1.00685D+01    |proj g|=  5.96856D-05
#
# At iterate   10    f=  1.00685D+01    |proj g|=  6.20659D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     14     25      1     0     0   0.000D+00   1.007D+01
#   F =   10.068500430995467
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00689D+01    |proj g|=  2.68052D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   0.000D+00   1.007D+01
#   F =   10.068939930381060
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00817D+01    |proj g|=  2.70184D-04
#
# At iterate    5    f=  1.00817D+01    |proj g|=  3.74811D-05
#
# At iterate   10    f=  1.00817D+01    |proj g|=  4.81393D-05
#
# At iterate   15    f=  1.00817D+01    |proj g|=  2.88303D-04
#
# At iterate   20    f=  1.00817D+01    |proj g|=  3.94351D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     21     41      1     0     0   0.000D+00   1.008D+01
#   F =   10.081728783138271
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.02924D+01    |proj g|=  2.79421D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   1.776D-07   1.029D+01
#   F =   10.292417353412093
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.02976D+01    |proj g|=  3.01270D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.030D+01
#   F =   10.297620511903530
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03756D+01    |proj g|=  2.83507D-04
#
# At iterate    5    f=  1.03756D+01    |proj g|=  1.24345D-06
#
# At iterate   10    f=  1.03756D+01    |proj g|=  2.48690D-06
#
# At iterate   15    f=  1.03756D+01    |proj g|=  6.57785D-04
#
# At iterate   20    f=  1.03756D+01    |proj g|=  2.13163D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     22     50      1     0     0   1.599D-06   1.038D+01
#   F =   10.375628713721840
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03860D+01    |proj g|=  3.05000D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   3.553D-07   1.039D+01
#   F =   10.385973609731066
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.04288D+01    |proj g|=  2.97007D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      6      1     0     0   1.243D-06   1.043D+01
#   F =   10.428839181029039
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.04452D+01    |proj g|=  3.12106D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   3.553D-07   1.045D+01
#   F =   10.445209891043167
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.04817D+01    |proj g|=  3.11040D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.048D+01
#   F =   10.481683862459146
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.04837D+01    |proj g|=  3.14238D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.048D+01
#   F =   10.483689092745346
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.04955D+01    |proj g|=  3.11040D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   1.776D-07   1.050D+01
#   F =   10.495508142258233
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05021D+01    |proj g|=  3.14593D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      7      1     0     0   0.000D+00   1.050D+01
#   F =   10.502116231629751
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05148D+01    |proj g|=  3.13882D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   1.776D-07   1.051D+01
#   F =   10.514803967842404
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05168D+01    |proj g|=  3.14593D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.052D+01
#   F =   10.516826060013399
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05212D+01    |proj g|=  3.12816D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.052D+01
#   F =   10.521221433923044
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05266D+01    |proj g|=  3.14060D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      8      1     0     0   0.000D+00   1.053D+01
#   F =   10.526550691838473
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05286D+01    |proj g|=  3.13349D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   1.776D-07   1.053D+01
#   F =   10.528623691605434
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05284D+01    |proj g|=  3.12284D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.053D+01
#   F =   10.528356897866555
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05290D+01    |proj g|=  3.11218D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.053D+01
#   F =   10.528964194507273
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05306D+01    |proj g|=  3.10862D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.053D+01
#   F =   10.530559958346167
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05312D+01    |proj g|=  3.09797D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.053D+01
#   F =   10.531234808523111
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05311D+01    |proj g|=  3.09264D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.053D+01
#   F =   10.531148468275452
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05323D+01    |proj g|=  3.08376D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.053D+01
#   F =   10.532314997841448
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05317D+01    |proj g|=  3.07487D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   1.776D-07   1.053D+01
#   F =   10.531696913675027
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05318D+01    |proj g|=  3.06244D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.053D+01
#   F =   10.531780753430006
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05315D+01    |proj g|=  3.05533D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.053D+01
#   F =   10.531511018957101
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05312D+01    |proj g|=  3.04823D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.053D+01
#   F =   10.531160508124639
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05306D+01    |proj g|=  3.04112D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   0.000D+00   1.053D+01
#   F =   10.530624583130319
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05300D+01    |proj g|=  3.03402D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.053D+01
#   F =   10.530034647245568
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05294D+01    |proj g|=  3.03224D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      8      1     0     0   1.776D-07   1.053D+01
#   F =   10.529374018862175
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05287D+01    |proj g|=  3.02336D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.053D+01
#   F =   10.528726432703143
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05281D+01    |proj g|=  3.01270D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.053D+01
#   F =   10.528060715264456
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05275D+01    |proj g|=  3.00737D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.053D+01
#   F =   10.527507123565663
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05268D+01    |proj g|=  3.00560D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   0.000D+00   1.053D+01
#   F =   10.526843396637840
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05262D+01    |proj g|=  2.99849D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.053D+01
#   F =   10.526179746809021
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05255D+01    |proj g|=  2.99138D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   0.000D+00   1.053D+01
#   F =   10.525523009612863
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05249D+01    |proj g|=  2.98783D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.052D+01
#   F =   10.524868248376974
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05243D+01    |proj g|=  2.98250D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.052D+01
#   F =   10.524297946610446
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05236D+01    |proj g|=  2.97895D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   1.776D-07   1.052D+01
#   F =   10.523629899403590
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05230D+01    |proj g|=  2.97362D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.052D+01
#   F =   10.522965453857665
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05223D+01    |proj g|=  2.97007D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      8      1     0     0   0.000D+00   1.052D+01
#   F =   10.522311188978554
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05217D+01    |proj g|=  2.96296D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.052D+01
#   F =   10.521694876219016
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05210D+01    |proj g|=  2.95941D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   1.776D-07   1.052D+01
#   F =   10.521049315345699
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05204D+01    |proj g|=  2.95586D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   1.776D-07   1.052D+01
#   F =   10.520397816528694
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05198D+01    |proj g|=  2.94875D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.052D+01
#   F =   10.519824682535967
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05192D+01    |proj g|=  2.94875D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.052D+01
#   F =   10.519204851163932
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05186D+01    |proj g|=  2.94342D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.052D+01
#   F =   10.518549984863860
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05179D+01    |proj g|=  2.93987D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   1.776D-07   1.052D+01
#   F =   10.517929890471551
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05173D+01    |proj g|=  2.93454D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   0.000D+00   1.052D+01
#   F =   10.517271313363631
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05167D+01    |proj g|=  2.93099D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   0.000D+00   1.052D+01
#   F =   10.516729973567786
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05161D+01    |proj g|=  2.92744D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   0.000D+00   1.052D+01
#   F =   10.516108584199953
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05155D+01    |proj g|=  2.92744D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3     14      1     0     0   1.776D-07   1.052D+01
#   F =   10.515507664971322
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05149D+01    |proj g|=  2.92211D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      8      1     0     0   0.000D+00   1.051D+01
#   F =   10.514925774191797
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05143D+01    |proj g|=  2.92033D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.051D+01
#   F =   10.514320084201454
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.05137D+01    |proj g|=  2.91855D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.051D+01
#   F =   10.513710133078737
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# ...
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03674D+01    |proj g|=  1.81366D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   0.000D+00   1.037D+01
#   F =   10.367374706414447
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03670D+01    |proj g|=  1.81544D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.037D+01
#   F =   10.366997098996739
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03667D+01    |proj g|=  1.81366D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.037D+01
#   F =   10.366692737772304
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03668D+01    |proj g|=  1.81011D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3     11      1     0     0   1.776D-07   1.037D+01
#   F =   10.366780940632765
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03672D+01    |proj g|=  1.80833D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      8      1     0     0   0.000D+00   1.037D+01
#   F =   10.367202541910201
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03668D+01    |proj g|=  1.80655D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.037D+01
#   F =   10.366818539565818
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03666D+01    |proj g|=  1.80478D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.037D+01
#   F =   10.366605234468899
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03662D+01    |proj g|=  1.80478D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.037D+01
#   F =   10.366188958923534
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03659D+01    |proj g|=  1.80300D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.037D+01
#   F =   10.365868107968181
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03654D+01    |proj g|=  1.80123D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.037D+01
#   F =   10.365430911378747
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03651D+01    |proj g|=  1.79945D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.037D+01
#   F =   10.365075787941828
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03647D+01    |proj g|=  1.79590D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.036D+01
#   F =   10.364734409347161
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03643D+01    |proj g|=  1.79767D-04
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.036D+01
#   F =   10.364312360713438
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03640D+01    |proj g|=  1.79590D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   0.000D+00   1.036D+01
#   F =   10.363956827605588
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03636D+01    |proj g|=  1.79234D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.036D+01
#   F =   10.363589073649591
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03632D+01    |proj g|=  1.79412D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.036D+01
#   F =   10.363239714117801
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03628D+01    |proj g|=  1.79412D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   0.000D+00   1.036D+01
#   F =   10.362820174608238
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03625D+01    |proj g|=  1.79412D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      9      1     0     0   1.776D-07   1.036D+01
#   F =   10.362502502834012
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03621D+01    |proj g|=  1.79234D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.036D+01
#   F =   10.362105519309484
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# Walk throught the test data, training and predicting 1 day ahead for all the test data
index = len(df_train)
yhat = list()
for t in track(range(len(df_test['New York']))):
    temp_train = ts_confirmed_US_incre[:index+t]
    model = ARMA(temp_train['New York'].diff().fillna(0),order=(1,1))
    model_fit = model.fit(transparams=False)
    predictions = model_fit.predict(len(temp_train),len(temp_train))
    yhat = yhat + [predictions]

yhat_ARMA = pd.concat(yhat)
resultsDict['ARMA'] = evaluate(df_test['New York'], yhat_ARMA.values)
predictionsDict['ARMA'] = yhat_ARMA.values
# Out:
# Output()
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.51750D+00    |proj g|=  1.15676D-03
#
# At iterate    5    f=  9.51750D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   0.000D+00   9.517D+00
#   F =   9.5174974279912270
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.56906D+00    |proj g|=  1.38094D-03
#
# At iterate    5    f=  9.56906D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   1.776D-07   9.569D+00
#   F =   9.5690605687915795
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.61133D+00    |proj g|=  1.49054D-03
#
# At iterate    5    f=  9.61133D+00    |proj g|=  5.32907D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   3.553D-07   9.611D+00
#   F =   9.6113320754716653
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.87359D+00    |proj g|=  1.75095D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      4      7      1     0     0   0.000D+00   9.874D+00
#   F =   9.8735868650390053
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.87293D+00    |proj g|=  1.75415D-03
#
# At iterate    5    f=  9.87293D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   1.776D-07   9.873D+00
#   F =   9.8729320806789360
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.87236D+00    |proj g|=  1.76463D-03
#
# At iterate    5    f=  9.87236D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   0.000D+00   9.872D+00
#   F =   9.8723619945066350
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.87384D+00    |proj g|=  1.74136D-03
#
# At iterate    5    f=  9.87384D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   1.776D-07   9.874D+00
#   F =   9.8738418387108755
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.87798D+00    |proj g|=  1.70868D-03
#
# At iterate    5    f=  9.87798D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6     10      1     0     0   1.776D-07   9.878D+00
#   F =   9.8779799000614670
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.87832D+00    |proj g|=  1.69376D-03
#
# At iterate    5    f=  9.87832D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   1.776D-07   9.878D+00
#   F =   9.8783205128211904
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.88124D+00    |proj g|=  1.66711D-03
#
# At iterate    5    f=  9.88123D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   1.776D-07   9.881D+00
#   F =   9.8812344626157582
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.89674D+00    |proj g|=  1.73390D-03
#
# At iterate    5    f=  9.89674D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   1.776D-07   9.897D+00
#   F =   9.8967390973669414
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.92100D+00    |proj g|=  1.72093D-03
#
# At iterate    5    f=  9.92100D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   1.776D-07   9.921D+00
#   F =   9.9210023860787171
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.92759D+00    |proj g|=  1.66747D-03
#
# At iterate    5    f=  9.92758D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   1.776D-07   9.928D+00
#   F =   9.9275845056312431
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.92718D+00    |proj g|=  1.65130D-03
#
# At iterate    5    f=  9.92718D+00    |proj g|=  3.55272D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   3.553D-07   9.927D+00
#   F =   9.9271824304312748
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.93311D+00    |proj g|=  1.60085D-03
#
# At iterate    5    f=  9.93311D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   0.000D+00   9.933D+00
#   F =   9.9331111374216814
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.94189D+00    |proj g|=  1.54348D-03
#
# At iterate    5    f=  9.94189D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6     13      1     0     0   0.000D+00   9.942D+00
#   F =   9.9418921550062525
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.94217D+00    |proj g|=  1.52234D-03
#
# At iterate    5    f=  9.94217D+00    |proj g|=  7.10543D-07
#
# At iterate   10    f=  9.94217D+00    |proj g|=  6.21725D-06
#
# At iterate   15    f=  9.94217D+00    |proj g|=  2.12985D-04
#
# At iterate   20    f=  9.94217D+00    |proj g|=  2.64677D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     24     37      1     0     0   7.105D-07   9.942D+00
#   F =   9.9421683810951063
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.94362D+00    |proj g|=  1.49516D-03
#
# At iterate    5    f=  9.94362D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      5      7      1     0     0   0.000D+00   9.944D+00
#   F =   9.9436198665500974
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.95674D+00    |proj g|=  1.44542D-03
#
# At iterate    5    f=  9.95674D+00    |proj g|=  5.32907D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   1.776D-07   9.957D+00
#   F =   9.9567378426456390
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96426D+00    |proj g|=  1.39284D-03
#
# At iterate    5    f=  9.96426D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   1.776D-07   9.964D+00
#   F =   9.9642621428576632
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96376D+00    |proj g|=  1.38307D-03
#
# At iterate    5    f=  9.96375D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   3.553D-07   9.964D+00
#   F =   9.9637544413641894
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96309D+00    |proj g|=  1.37934D-03
#
# At iterate    5    f=  9.96309D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   3.553D-07   9.963D+00
#   F =   9.9630903900526651
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96379D+00    |proj g|=  1.36868D-03
#
# At iterate    5    f=  9.96379D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      5      7      1     0     0   0.000D+00   9.964D+00
#   F =   9.9637862264719494
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96318D+00    |proj g|=  1.36495D-03
#
# At iterate    5    f=  9.96318D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   1.776D-07   9.963D+00
#   F =   9.9631786870834720
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96741D+00    |proj g|=  1.34914D-03
#
# At iterate    5    f=  9.96741D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   1.776D-07   9.967D+00
#   F =   9.9674135597737035
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96883D+00    |proj g|=  1.33848D-03
#
# At iterate    5    f=  9.96883D+00    |proj g|=  1.42109D-06
#
# At iterate   10    f=  9.96883D+00    |proj g|=  6.55476D-05
#
# At iterate   15    f=  9.96883D+00    |proj g|=  1.43068D-03
#
# At iterate   20    f=  9.96882D+00    |proj g|=  8.34888D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     23     33      1     0     0   3.553D-07   9.969D+00
#   F =   9.9688242405136052
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96815D+00    |proj g|=  1.33653D-03
#
# At iterate    5    f=  9.96815D+00    |proj g|=  3.55271D-07
#
# At iterate   10    f=  9.96815D+00    |proj g|=  1.59872D-06
#
# At iterate   15    f=  9.96815D+00    |proj g|=  3.21521D-05
#
# At iterate   20    f=  9.96815D+00    |proj g|=  4.15845D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     24     41      1     0     0   1.243D-06   9.968D+00
#   F =   9.9681472776698055
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96749D+00    |proj g|=  1.33422D-03
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  9.96749D+00    |proj g|=  5.32907D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   3.553D-07   9.967D+00
#   F =   9.9674859042652511
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96714D+00    |proj g|=  1.33067D-03
#
# At iterate    5    f=  9.96714D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      5      7      1     0     0   0.000D+00   9.967D+00
#   F =   9.9671422326538011
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96705D+00    |proj g|=  1.32623D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  9.96705D+00    |proj g|=  1.06581D-06
#
# At iterate   10    f=  9.96705D+00    |proj g|=  2.46914D-05
#
# At iterate   15    f=  9.96705D+00    |proj g|=  2.10143D-04
#
# At iterate   20    f=  9.96705D+00    |proj g|=  2.13163D-05
#
# At iterate   25    f=  9.96705D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     25     42      1     0     0   3.553D-07   9.967D+00
#   F =   9.9670474547227137
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96812D+00    |proj g|=  1.32001D-03
#
# At iterate    5    f=  9.96812D+00    |proj g|=  1.59872D-06
#
# At iterate   10    f=  9.96812D+00    |proj g|=  4.92051D-05
#
# At iterate   15    f=  9.96812D+00    |proj g|=  1.15321D-03
#
# At iterate   20    f=  9.96812D+00    |proj g|=  1.36549D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     23     27      1     0     0   3.890D-05   9.968D+00
#   F =   9.9681181562420367
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96814D+00    |proj g|=  1.31255D-03
#
# At iterate    5    f=  9.96814D+00    |proj g|=  7.10543D-07
#
# At iterate   10    f=  9.96814D+00    |proj g|=  6.51923D-05
#
# At iterate   15    f=  9.96814D+00    |proj g|=  4.30589D-04
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   20    f=  9.96814D+00    |proj g|=  5.68434D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     23     57      2     0     0   3.553D-07   9.968D+00
#   F =   9.9681424171681510
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96781D+00    |proj g|=  1.30722D-03
#
# At iterate    5    f=  9.96781D+00    |proj g|=  7.10543D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   5.329D-07   9.968D+00
#   F =   9.9678075136703566
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96716D+00    |proj g|=  1.30616D-03
#
# At iterate    5    f=  9.96716D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   3.553D-07   9.967D+00
#   F =   9.9671561658691417
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96653D+00    |proj g|=  1.30509D-03
#
# At iterate    5    f=  9.96653D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      8     18      1     0     0   4.619D-06   9.967D+00
#   F =   9.9665322753336518
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96588D+00    |proj g|=  1.30349D-03
#
# At iterate    5    f=  9.96588D+00    |proj g|=  5.32907D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   5.329D-07   9.966D+00
#   F =   9.9658813183074972
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96548D+00    |proj g|=  1.30118D-03
#
# At iterate    5    f=  9.96548D+00    |proj g|=  7.10543D-07
#
# At iterate   10    f=  9.96548D+00    |proj g|=  5.76250D-04
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   15    f=  9.96548D+00    |proj g|=  1.28608D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     18     28      1     0     0   1.776D-07   9.965D+00
#   F =   9.9654817322977109
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96484D+00    |proj g|=  1.29923D-03
#
# At iterate    5    f=  9.96484D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   1.776D-07   9.965D+00
#   F =   9.9648385270483306
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96448D+00    |proj g|=  1.29639D-03
#
# At iterate    5    f=  9.96448D+00    |proj g|=  8.88178D-07
#
# At iterate   10    f=  9.96448D+00    |proj g|=  5.75540D-05
#
# At iterate   15    f=  9.96448D+00    |proj g|=  2.53486D-04
#
# At iterate   20    f=  9.96447D+00    |proj g|=  5.17630D-04
#
# At iterate   25    f=  9.96447D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     25     35      1     0     0   1.776D-07   9.964D+00
#   F =   9.9644748303256634
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96394D+00    |proj g|=  1.29408D-03
#
# At iterate    5    f=  9.96394D+00    |proj g|=  1.77636D-07
#
# At iterate   10    f=  9.96394D+00    |proj g|=  1.15463D-05
#
# At iterate   15    f=  9.96394D+00    |proj g|=  3.60600D-05
#
# At iterate   20    f=  9.96394D+00    |proj g|=  4.44622D-04
#
# At iterate   25    f=  9.96394D+00    |proj g|=  9.11271D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     28     55      1     0     0   5.880D-05   9.964D+00
#   F =   9.9639382023282739
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96327D+00    |proj g|=  1.29248D-03
#
# At iterate    5    f=  9.96327D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   1.776D-07   9.963D+00
#   F =   9.9632744635973989
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96273D+00    |proj g|=  1.29123D-03
#
# At iterate    5    f=  9.96273D+00    |proj g|=  5.32907D-07
#
# At iterate   10    f=  9.96273D+00    |proj g|=  3.73035D-06
#
# At iterate   15    f=  9.96273D+00    |proj g|=  3.90799D-06
#
# At iterate   20    f=  9.96273D+00    |proj g|=  3.55271D-06
#
# At iterate   25    f=  9.96273D+00    |proj g|=  5.32907D-07
#
# At iterate   30    f=  9.96273D+00    |proj g|=  3.26850D-05
#
# At iterate   35    f=  9.96273D+00    |proj g|=  1.73728D-04
#
# At iterate   40    f=  9.96273D+00    |proj g|=  1.14575D-04
#
# At iterate   45    f=  9.96273D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     46     71      1     0     0   1.776D-07   9.963D+00
#   F =   9.9627288538963246
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96209D+00    |proj g|=  1.28946D-03
#
# At iterate    5    f=  9.96209D+00    |proj g|=  5.32907D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   5.329D-07   9.962D+00
#   F =   9.9620899927836906
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96158D+00    |proj g|=  1.28786D-03
#
# At iterate    5    f=  9.96158D+00    |proj g|=  5.32907D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   5.329D-07   9.962D+00
#   F =   9.9615781728101656
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96093D+00    |proj g|=  1.28608D-03
#
# At iterate    5    f=  9.96093D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      5      7      1     0     0   0.000D+00   9.961D+00
#   F =   9.9609297842955584
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.96038D+00    |proj g|=  1.28377D-03
#
# At iterate    5    f=  9.96038D+00    |proj g|=  3.55271D-07
#
# At iterate   10    f=  9.96038D+00    |proj g|=  2.16716D-05
#
# At iterate   15    f=  9.96038D+00    |proj g|=  3.61133D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     19     24      1     0     0   0.000D+00   9.960D+00
#   F =   9.9603797176890474
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.95980D+00    |proj g|=  1.28200D-03
#
# At iterate    5    f=  9.95980D+00    |proj g|=  3.55271D-07
#
# At iterate   10    f=  9.95980D+00    |proj g|=  1.08358D-05
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
# At iterate   15    f=  9.95980D+00    |proj g|=  2.08722D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     19     46      1     0     0   5.542D-04   9.960D+00
#   F =   9.9597997265126494
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.95916D+00    |proj g|=  1.28004D-03
#
# At iterate    5    f=  9.95916D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   3.553D-07   9.959D+00
#   F =   9.9591620412984607
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.95851D+00    |proj g|=  1.27898D-03
#
# At iterate    5    f=  9.95851D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   0.000D+00   9.959D+00
#   F =   9.9585075841666217
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.95789D+00    |proj g|=  1.27738D-03
#
# At iterate    5    f=  9.95788D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      7     12      1     0     0   1.776D-07   9.958D+00
#   F =   9.9578846804968482
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  9.95604D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# ...
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   3.553D-07   9.864D+00
#   F =   9.8640413071123838
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86362D+00    |proj g|=  9.37383D-04
#
# At iterate    5    f=  9.86362D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   3.553D-07   9.864D+00
#   F =   9.8636188237740221
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86583D+00    |proj g|=  9.37739D-04
#
# At iterate    5    f=  9.86583D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   0.000D+00   9.866D+00
#   F =   9.8658336551514072
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86554D+00    |proj g|=  9.37916D-04
#
# At iterate    5    f=  9.86554D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   1.776D-07   9.866D+00
#   F =   9.8655405403589729
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86515D+00    |proj g|=  9.37383D-04
#
# At iterate    5    f=  9.86515D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   3.553D-07   9.865D+00
#   F =   9.8651456421277874
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86472D+00    |proj g|=  9.36318D-04
#
# At iterate    5    f=  9.86472D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6     10      1     0     0   3.553D-07   9.865D+00
#   F =   9.8647224228305426
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86434D+00    |proj g|=  9.35785D-04
#
# At iterate    5    f=  9.86434D+00    |proj g|=  3.55271D-07
#
# At iterate   10    f=  9.86434D+00    |proj g|=  1.54543D-05
#
# At iterate   15    f=  9.86434D+00    |proj g|=  2.04281D-05
#
# At iterate   20    f=  9.86434D+00    |proj g|=  6.64357D-05
#
# At iterate   25    f=  9.86434D+00    |proj g|=  1.04983D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     28     41      1     0     0   1.776D-07   9.864D+00
#   F =   9.8643433435899652
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86394D+00    |proj g|=  9.34719D-04
#
# At iterate    5    f=  9.86394D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   5.329D-07   9.864D+00
#   F =   9.8639382959339930
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86353D+00    |proj g|=  9.34364D-04
#
# At iterate    5    f=  9.86353D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   3.553D-07   9.864D+00
#   F =   9.8635279643734535
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86309D+00    |proj g|=  9.33298D-04
#
# At iterate    5    f=  9.86309D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   0.000D+00   9.863D+00
#   F =   9.8630894025350582
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86271D+00    |proj g|=  9.32410D-04
#
# At iterate    5    f=  9.86271D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   3.553D-07   9.863D+00
#   F =   9.8627073370309990
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86227D+00    |proj g|=  9.31699D-04
#
# At iterate    5    f=  9.86227D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   1.776D-07   9.862D+00
#   F =   9.8622729511827067
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86183D+00    |proj g|=  9.30811D-04
#
# At iterate    5    f=  9.86183D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   3.553D-07   9.862D+00
#   F =   9.8618330363631994
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86141D+00    |proj g|=  9.29745D-04
#
# At iterate    5    f=  9.86141D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6     10      1     0     0   7.105D-07   9.861D+00
#   F =   9.8614070008108374
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86098D+00    |proj g|=  9.29212D-04
#
# At iterate    5    f=  9.86098D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   3.553D-07   9.861D+00
#   F =   9.8609829710538364
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86057D+00    |proj g|=  9.28502D-04
#
# At iterate    5    f=  9.86057D+00    |proj g|=  3.55271D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   5.329D-07   9.861D+00
#   F =   9.8605684798886593
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.86013D+00    |proj g|=  9.27258D-04
#
# At iterate    5    f=  9.86013D+00    |proj g|=  1.77636D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      9      1     0     0   3.553D-07   9.860D+00
#   F =   9.8601324459112920
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.85970D+00    |proj g|=  9.27258D-04
#
# At iterate    5    f=  9.85970D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      5      7      1     0     0   0.000D+00   9.860D+00
#   F =   9.8596950374098249
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
index = len(df_train)
yhat = list()
for t in track(range(len(df_test['New York']))):
    temp_train = ts_confirmed_US_incre[:index+t]
    model = ARIMA(temp_train['New York'],order=(1,0,0))
    model_fit = model.fit(transparams=False)
    predictions = model_fit.predict(len(temp_train),len(temp_train))
    yhat = yhat + [predictions]

yhat_ARIMA = pd.concat(yhat)
resultsDict['ARIMA'] = evaluate(df_test['New York'], yhat_ARIMA.values)
predictionsDict['ARIMA'] = yhat_ARIMA.values
# Out:
# Output()
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.75071D+00    |proj g|=  4.10072D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   5.329D-07   9.751D+00
#   F =   9.7507039518856011
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.78526D+00    |proj g|=  1.01679D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   9.785D+00
#   F =   9.7852583866919485
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.78484D+00    |proj g|=  2.08242D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   3.553D-07   9.785D+00
#   F =   9.7848378947115737
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00749D+01    |proj g|=  5.74367D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   3.553D-07   1.007D+01
#   F =   10.074867974161661
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01381D+01    |proj g|=  1.61062D-03
#
# At iterate    5    f=  1.01381D+01    |proj g|=  8.91731D-05
#
# At iterate   10    f=  1.01381D+01    |proj g|=  4.08562D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     10     26      1     0     0   4.086D-06   1.014D+01
#   F =   10.138050261555378
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01597D+01    |proj g|=  1.94795D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   3.553D-07   1.016D+01
#   F =   10.159677303276665
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01643D+01    |proj g|=  2.21760D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  1.01643D+01    |proj g|=  1.95399D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6     12      1     0     0   2.309D-06   1.016D+01
#   F =   10.164311783076679
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01711D+01    |proj g|=  2.46256D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3     30      2     0     0   1.776D-07   1.017D+01
#   F =   10.171098752617912
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01723D+01    |proj g|=  2.82192D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4     32      1     0     0   6.917D-04   1.017D+01
#   F =   10.172280985365484
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01790D+01    |proj g|=  3.31895D-03
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01872D+01    |proj g|=  5.29070D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   0.000D+00   1.019D+01
#   F =   10.187238031328414
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01873D+01    |proj g|=  2.97078D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   1.776D-07   1.019D+01
#   F =   10.187254738430747
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01866D+01    |proj g|=  2.95604D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.019D+01
#   F =   10.186565780765397
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01881D+01    |proj g|=  3.04539D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.019D+01
#   F =   10.188118473676221
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01874D+01    |proj g|=  3.01323D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   1.776D-07   1.019D+01
#   F =   10.187434892094577
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01886D+01    |proj g|=  2.90683D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.019D+01
#   F =   10.188634253350902
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01880D+01    |proj g|=  2.90168D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.019D+01
#   F =   10.187994241011145
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01889D+01    |proj g|=  2.93063D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   1.776D-07   1.019D+01
#   F =   10.188908206221242
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01883D+01    |proj g|=  2.92850D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      8      1     0     0   0.000D+00   1.019D+01
#   F =   10.188314061896017
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01878D+01    |proj g|=  2.89813D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   0.000D+00   1.019D+01
#   F =   10.187773789681394
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01878D+01    |proj g|=  2.91092D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   1.776D-07   1.019D+01
#   F =   10.187773751187477
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01890D+01    |proj g|=  2.85123D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   0.000D+00   1.019D+01
#   F =   10.189018768219517
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01885D+01    |proj g|=  2.84714D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      8      1     0     0   0.000D+00   1.019D+01
#   F =   10.188481684171009
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01884D+01    |proj g|=  2.84874D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   0.000D+00   1.019D+01
#   F =   10.188382177778683
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01877D+01    |proj g|=  2.83720D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   0.000D+00   1.019D+01
#   F =   10.187702851476788
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01870D+01    |proj g|=  2.82547D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.019D+01
#   F =   10.187038268834838
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01864D+01    |proj g|=  2.81553D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.019D+01
#   F =   10.186374159459067
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01860D+01    |proj g|=  2.80433D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.019D+01
#   F =   10.185996881971501
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01853D+01    |proj g|=  2.79865D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.019D+01
#   F =   10.185326321491544
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01847D+01    |proj g|=  2.79314D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3     33      2     0     0   1.776D-07   1.018D+01
#   F =   10.184662226489266
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01842D+01    |proj g|=  2.78657D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   0.000D+00   1.018D+01
#   F =   10.184153357959920
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01835D+01    |proj g|=  2.78018D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   1.776D-07   1.018D+01
#   F =   10.183485439757385
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01828D+01    |proj g|=  2.77343D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   0.000D+00   1.018D+01
#   F =   10.182834484550874
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01822D+01    |proj g|=  2.76774D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   1.776D-07   1.018D+01
#   F =   10.182234689192272
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01816D+01    |proj g|=  2.76170D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.018D+01
#   F =   10.181587854812227
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01811D+01    |proj g|=  2.75797D-03
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.018D+01
#   F =   10.181082214337923
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01804D+01    |proj g|=  2.75371D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   1.776D-07   1.018D+01
#   F =   10.180412986894257
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01798D+01    |proj g|=  2.74820D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   1.776D-07   1.018D+01
#   F =   10.179766706319732
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01791D+01    |proj g|=  2.74252D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3     44      2     0     0   1.776D-07   1.018D+01
#   F =   10.179135671486137
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01786D+01    |proj g|=  2.73808D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.018D+01
#   F =   10.178568635216221
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01779D+01    |proj g|=  2.73470D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   1.776D-07   1.018D+01
#   F =   10.177940138440748
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01773D+01    |proj g|=  2.73044D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.018D+01
#   F =   10.177277610273842
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01767D+01    |proj g|=  2.72848D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.018D+01
#   F =   10.176695433840525
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after 20 function
#   and gradient evaluations.  Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01760D+01    |proj g|=  2.72600D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.018D+01
#   F =   10.176043155513945
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01754D+01    |proj g|=  2.72067D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.018D+01
#   F =   10.175409808561657
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01748D+01    |proj g|=  2.71729D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.017D+01
#   F =   10.174760837805758
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01741D+01    |proj g|=  2.71267D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.017D+01
#   F =   10.174107480166677
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01736D+01    |proj g|=  2.71072D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   0.000D+00   1.017D+01
#   F =   10.173558084890441
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01729D+01    |proj g|=  2.70894D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   1.776D-07   1.017D+01
#   F =   10.172914507771210
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01723D+01    |proj g|=  2.70557D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   3.553D-07   1.017D+01
#   F =   10.172257309909831
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01716D+01    |proj g|=  2.70397D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.017D+01
#   F =   10.171627710747087
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01710D+01    |proj g|=  2.70131D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.017D+01
#   F =   10.170974082725406
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01703D+01    |proj g|=  2.69829D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   1.776D-07   1.017D+01
#   F =   10.170319516338512
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01697D+01    |proj g|=  2.69580D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   1.776D-07   1.017D+01
#   F =   10.169678532957818
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01690D+01    |proj g|=  2.69438D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.017D+01
#   F =   10.169046327695849
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01684D+01    |proj g|=  2.69154D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.017D+01
#   F =   10.168396747138026
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01678D+01    |proj g|=  2.69100D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
# ...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00760D+01    |proj g|=  1.37845D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.008D+01
#   F =   10.075971180627491
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00755D+01    |proj g|=  1.37863D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   1.776D-07   1.008D+01
#   F =   10.075542386553675
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00751D+01    |proj g|=  1.37881D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.008D+01
#   F =   10.075113948326869
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00763D+01    |proj g|=  1.37081D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.008D+01
#   F =   10.076261837109916
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00774D+01    |proj g|=  1.36566D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.008D+01
#   F =   10.077404797623254
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00770D+01    |proj g|=  1.36371D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.008D+01
#   F =   10.076998121099340
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00766D+01    |proj g|=  1.36300D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      7      1     0     0   1.776D-07   1.008D+01
#   F =   10.076578655590113
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00762D+01    |proj g|=  1.36300D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3     31      2     0     0   3.553D-07   1.008D+01
#   F =   10.076177359937743
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00757D+01    |proj g|=  1.36300D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.008D+01
#   F =   10.075748798938776
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00753D+01    |proj g|=  1.36158D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.008D+01
#   F =   10.075322804360228
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00749D+01    |proj g|=  1.36069D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.007D+01
#   F =   10.074905799747071
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00745D+01    |proj g|=  1.36104D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      4      1     0     0   0.000D+00   1.007D+01
#   F =   10.074544017215398
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00741D+01    |proj g|=  1.35962D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      8      1     0     0   0.000D+00   1.007D+01
#   F =   10.074113952769647
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00737D+01    |proj g|=  1.35945D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      9      1     0     0   1.776D-07   1.007D+01
#   F =   10.073695995186906
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00733D+01    |proj g|=  1.35927D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   1.776D-07   1.007D+01
#   F =   10.073287428988490
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00729D+01    |proj g|=  1.35927D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.007D+01
#   F =   10.072865295018488
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00724D+01    |proj g|=  1.35785D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   0.000D+00   1.007D+01
#   F =   10.072432168478610
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00720D+01    |proj g|=  1.35802D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   0.000D+00   1.007D+01
#   F =   10.072048179756690
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           12
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00716D+01    |proj g|=  1.35749D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   0.000D+00   1.007D+01
#   F =   10.071614348431938
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
autoModel = pm.auto_arima(df_train['New York'], trace=True,
                          error_action='ignore', suppress_warnings=True, seasonal=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 autoModel = pm.auto_arima(df_train['New York'], trace=True,
#       2                           error_action='ignore', suppress_warnings=True, seasonal=True)
#
# NameError: name 'pm' is not defined

# %%
# Now you can access the order
best_order = autoModel.order
model0 = ARIMA(df_train['New York'], order=best_order)
model_fit0 = model0.fit(disp=False)

best_order = autoModel.order
model0 = ARIMA(df_train['New York'],order = best_order)
model_fit0 =model0.fit(disp=False)
yhat = list()
for t in track(range(len(df_test['New York']))):
    temp_train = ts_confirmed_US_incre[:index+t]
    model = ARIMA(temp_train['New York'],order=best_order)
    model_fit = model.fit(disp=False,transparams=False,start_params = model_fit.params)
    predictions = model_fit.predict(len(temp_train),len(temp_train),dynamic = False)
    yhat = yhat + [predictions]
    
yhat_autoarima = pd.concat(yhat)
resultsDict['AutoARIMA {0}'.format(best_order)] = evaluate(
    df_test['New York'], yhat_autoarima)
predictionsDict['AutoARIMA {0}'.format(best_order)] = yhat_autoarima.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 best_order = autoModel.order
#       2 model0 = ARIMA(df_train['New York'],order = best_order)
#       3 model_fit0 =model0.fit(disp=False)
#
# NameError: name 'autoModel' is not defined

# %%
# Walk throught the test data, training and predicting 1 day ahead for all the test data
index = len(df_train)
yhat = list()
for t in track(range(len(df_test['New York']))):
    temp_train = ts_confirmed_US_incre[:index+t]
    model = SARIMAX(temp_train['New York'],order=(1,0,0), seansonal_order=(0,0,0,3))
    model_fit = model.fit(disp=False,transparams=False)
    predictions = model_fit.predict(len(temp_train),len(temp_train),dynamic = False)
    yhat = yhat + [predictions]
    
yhat_SARIMAX = pd.concat(yhat)
resultsDict['SARIMAX'] = evaluate(df_test['New York'], yhat_SARIMAX.values)
predictionsDict['SARIMAX'] = yhat_SARIMAX.values

# %%
autoModel = pm.auto_arima(df_train['New York'], trace=True, error_action='ignore',
                          suppress_warnings=True, seasonal=True, m=6, stepwise=True)

# %%
best_order = autoModel.order
seasonalOrder = autoModel.seasonal_order
# model0 = ARIMA(df_train['New York'],order = best_order)
# model_fit0 =model0.fit(disp=False)
yhat = list()
for t in track(range(len(df_test['New York']))):
    temp_train = ts_confirmed_US_incre[:index+t]
    model = SARIMAX(temp_train['New York'],order=best_order, seansonal_order=seasonalOrder)
    model_fit = model.fit(disp=False,transparams=False)
    predictions = model_fit.predict(len(temp_train),len(temp_train),dynamic = False)
    yhat = yhat + [predictions]
    
yhat_AutoSARIMAX = pd.concat(yhat)
resultsDict['AutoSARIMAX  {0}'.format(best_order,seasonalOrder)] = evaluate(
    df_test['New York'], yhat_AutoSARIMAX)
predictionsDict['AutoSARIMAX  {0}'.format(best_order,seasonalOrder)] = yhat_AutoSARIMAX.values

# %%
yhat_dict = {
    'SES':yhat_SES,
    'HWES':yhat_HWES,
    'AR':yhat_AR,
    'MA':yhat_MA,
    'ARMA':yhat_ARMA,
    'ARIMA':yhat_ARIMA,
    'AUTOARIMA':yhat_autoarima,
    'SARIMAX':yhat_SARIMAX,
    'AUTOSARIMAX':yhat_AutoSARIMAX
}

# %%
fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(3*15, 10*3))
plt.subplots_adjust(hspace=0.5)
plt.suptitle("New York Time Series Prediction Using 9 Univariate Forecasting Methods", fontsize=50, y = .96)
for yhat_key,ax in zip(yhat_dict.keys(), axs.ravel()):
    df_test['New York'].plot(ax=ax,alpha = .5, label = "New York Original Series", color = '#06c3cc')
    yhat_dict[yhat_key].plot(ax=ax,color = 'red',label=f'{yhat_key} Predicted')
    ax.set_title(f"{yhat_key.upper()}",fontsize = 35)
    ax.legend(fontsize = 25)
    ax.set_xlabel("")
plt.show()
